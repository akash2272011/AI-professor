# %% [markdown]
# <a href="https://colab.research.google.com/github/akash2272011/AI-professor/blob/main/Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet flashtext==2.7
# !pip install git+https://github.com/boudinfl/pke.git
# Out:
#   Preparing metadata (setup.py) ... done
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/boudinfl/pke.git to /tmp/pip-req-build-2aii8mcn
#   Running command git clone --filter=blob:none --quiet https://github.com/boudinfl/pke.git /tmp/pip-req-build-2aii8mcn
#   Resolved https://github.com/boudinfl/pke.git to commit f2d4f5d2252c64d23defccd32fdac8809cfd7ce0
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for pke: filename=pke-2.0.0-py3-none-any.whl size=6160676 sha256=41869a9d9796405e8639ef347bce2e16f2362ccfbcf16391ebb523e551596184
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ync5sk2f/wheels/d5/46/97/85535b5b449f70b6a3c8d1138ce8587345876891e25bfe7954
# Successfully built pke
# ...

# %%
# !pip install --quiet transformers==4.8.1
# !pip install --quiet sentencepiece==0.1.95
# !pip install --quiet textwrap3==0.9.2
# !pip install --quiet gradio==3.0.20
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 53.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 57.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 46.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 20.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 5.8 MB/s eta 0:00:00
# ...

# %%
# !pip install --quiet strsim==0.0.3
# !pip install --quiet sense2vec==2.0.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.9 MB/s eta 0:00:00

# %%
# !pip install --quiet ipython-autotime
# %load_ext autotime
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00
# time: 630 µs (started: 2023-04-11 09:31:57 +00:00)

# %%
# !pip install --quiet sentence-transformers==2.2.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 57.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.7 MB/s eta 0:00:00
# ...
# time: 25.5 s (started: 2023-04-11 09:31:57 +00:00)

# %%
# import os
# os.kill(os.getpid(), 9)
# Out:
# time: 432 µs (started: 2023-04-11 09:32:23 +00:00)

# %%
from textwrap3 import wrap

text = """Elon Musk has shown again he can influence the digital currency market with just his tweets. After saying that his electric vehicle-making company
Tesla will not accept payments in Bitcoin because of environmental concerns, he tweeted that he was working with developers of Dogecoin to improve
system transaction efficiency. Following the two distinct statements from him, the world's largest cryptocurrency hit a two-month low, while Dogecoin
rallied by about 20 percent. The SpaceX CEO has in recent months often tweeted in support of Dogecoin, but rarely for Bitcoin.  In a recent tweet,
Musk put out a statement from Tesla that it was “concerned” about the rapidly increasing use of fossil fuels for Bitcoin (price in India) mining and
transaction, and hence was suspending vehicle purchases using the cryptocurrency.  A day later he again tweeted saying, “To be clear, I strongly
believe in crypto, but it can't drive a massive increase in fossil fuel use, especially coal”.  It triggered a downward spiral for Bitcoin value but
the cryptocurrency has stabilised since.   A number of Twitter users welcomed Musk's statement. One of them said it's time people started realising
that Dogecoin “is here to stay” and another referred to Musk's previous assertion that crypto could become the world's future currency."""

for wrp in wrap(text, 150):
  print (wrp)
print ("\n")
# Out:
# Elon Musk has shown again he can influence the digital currency market with just his tweets. After saying that his electric vehicle-making company
# Tesla will not accept payments in Bitcoin because of environmental concerns, he tweeted that he was working with developers of Dogecoin to improve
# system transaction efficiency. Following the two distinct statements from him, the world's largest cryptocurrency hit a two-month low, while Dogecoin
# rallied by about 20 percent. The SpaceX CEO has in recent months often tweeted in support of Dogecoin, but rarely for Bitcoin.  In a recent tweet,
# Musk put out a statement from Tesla that it was “concerned” about the rapidly increasing use of fossil fuels for Bitcoin (price in India) mining and
# transaction, and hence was suspending vehicle purchases using the cryptocurrency.  A day later he again tweeted saying, “To be clear, I strongly
# ...

# %%
text = """ Once, there was a boy who became bored when he watched over the village sheep grazing on the hillside. To entertain himself, he sang out, “Wolf! Wolf! The wolf is chasing the sheep!”
When the villagers heard the cry, they came running up the hill to drive the wolf away. But, when they arrived, they saw no wolf. The boy was amused when seeing their angry faces.

“Don’t scream wolf, boy,” warned the villagers, “when there is no wolf!” They angrily went back down the hill.

Later, the shepherd boy cried out once again, “Wolf! Wolf! The wolf is chasing the sheep!” To his amusement, he looked on as the villagers came running up the hill to scare the wolf away.

As they saw there was no wolf, they said strictly, “Save your frightened cry for when there really is a wolf! Don’t cry ‘wolf’ when there is no wolf!” But the boy grinned at their words while they walked grumbling down the hill once more.

Later, the boy saw a real wolf sneaking around his flock. Alarmed, he jumped on his feet and cried out as loud as he could, “Wolf! Wolf!” But the villagers thought he was fooling them again, and so they didn’t come to help.

At sunset, the villagers went looking for the boy who hadn’t returned with their sheep. When they went up the hill, they found him weeping.

“There really was a wolf here! The flock is gone! I cried out, ‘Wolf!’ but you didn’t come,” he wailed.

An old man went to comfort the boy. As he put his arm around him, he said, “Nobody believes a liar, even when he is telling the truth!” """
for wrp in wrap(text, 150):
  print (wrp)
print ("\n")
# Out:
#  Once, there was a boy who became bored when he watched over the village sheep grazing on the hillside. To entertain himself, he sang out, “Wolf!
# Wolf! The wolf is chasing the sheep!” When the villagers heard the cry, they came running up the hill to drive the wolf away. But, when they arrived,
# they saw no wolf. The boy was amused when seeing their angry faces.  “Don’t scream wolf, boy,” warned the villagers, “when there is no wolf!” They
# angrily went back down the hill.  Later, the shepherd boy cried out once again, “Wolf! Wolf! The wolf is chasing the sheep!” To his amusement, he
# looked on as the villagers came running up the hill to scare the wolf away.  As they saw there was no wolf, they said strictly, “Save your frightened
# cry for when there really is a wolf! Don’t cry ‘wolf’ when there is no wolf!” But the boy grinned at their words while they walked grumbling down the
# ...

# %%
import torch
from transformers import T5ForConditionalGeneration,T5Tokenizer
summary_model = T5ForConditionalGeneration.from_pretrained('t5-base')
summary_tokenizer = T5Tokenizer.from_pretrained('t5-base')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
summary_model = summary_model.to(device)
# Out:
# ...
# time: 29.9 s (started: 2023-04-11 09:32:23 +00:00)
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
import random
import numpy as np

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)
# Out:
# time: 6.6 ms (started: 2023-04-11 09:32:53 +00:00)

# %%
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.tokenize import sent_tokenize

def postprocesstext (content):
  final=""
  for sent in sent_tokenize(content):
    sent = sent.capitalize()
    final = final +" "+sent
  return final


def summarizer(text,model,tokenizer):
  text = text.strip().replace("\n"," ")
  text = "summarize: "+text
  # print (text)
  max_len = 512
  encoding = tokenizer.encode_plus(text,max_length=max_len, pad_to_max_length=False,truncation=True, return_tensors="pt").to(device)

  input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

  outs = model.generate(input_ids=input_ids,
                                  attention_mask=attention_mask,
                                  early_stopping=True,
                                  num_beams=3,
                                  num_return_sequences=1,
                                  no_repeat_ngram_size=2,
                                  min_length = 75,
                                  max_length=300)


  dec = [tokenizer.decode(ids,skip_special_tokens=True) for ids in outs]
  summary = dec[0]
  summary = postprocesstext(summary)
  summary= summary.strip()

  return summary


summarized_text = summarizer(text,summary_model,summary_tokenizer)


print ("\noriginal Text >>")
for wrp in wrap(text, 150):
  print (wrp)
print ("\n")
print ("Summarized Text >>")
for wrp in wrap(summarized_text, 150):
  print (wrp)
print ("\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# original Text >>
#  Once, there was a boy who became bored when he watched over the village sheep grazing on the hillside. To entertain himself, he sang out, “Wolf!
# Wolf! The wolf is chasing the sheep!” When the villagers heard the cry, they came running up the hill to drive the wolf away. But, when they arrived,
# they saw no wolf. The boy was amused when seeing their angry faces.  “Don’t scream wolf, boy,” warned the villagers, “when there is no wolf!” They
# angrily went back down the hill.  Later, the shepherd boy cried out once again, “Wolf! Wolf! The wolf is chasing the sheep!” To his amusement, he
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
import pke
import traceback

def get_nouns_multipartite(content):
    out=[]
    try:
        extractor = pke.unsupervised.MultipartiteRank()
        extractor.load_document(input=content,language='en')
        pos = {'PROPN','NOUN'}
        stoplist = list(string.punctuation)
        stoplist += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
        stoplist += stopwords.words('english')
        extractor.candidate_selection(pos=pos)
        extractor.candidate_weighting(alpha=1.1,
                                      threshold=0.75,
                                      method='average')
        keyphrases = extractor.get_n_best(n=15)
        

        for val in keyphrases:
            out.append(val[0])
    except:
        out = []
        traceback.print_exc()

    return out
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# time: 11.6 s (started: 2023-04-11 09:33:25 +00:00)

# %%
from flashtext import KeywordProcessor


def get_keywords(originaltext,summarytext):
  keywords = get_nouns_multipartite(originaltext)
  print ("keywords unsummarized: ",keywords)
  keyword_processor = KeywordProcessor()
  for keyword in keywords:
    keyword_processor.add_keyword(keyword)

  keywords_found = keyword_processor.extract_keywords(summarytext)
  keywords_found = list(set(keywords_found))
  print ("keywords_found in summarized: ",keywords_found)

  important_keywords =[]
  for keyword in keywords:
    if keyword in keywords_found:
      important_keywords.append(keyword)

  return important_keywords[:4]


imp_keywords = get_keywords(text,summarized_text)
print (imp_keywords)
# Out:
# keywords unsummarized:  ['wolf', 'village sheep', 'boy', 'hill', 'villagers', 'hillside', 'sheep', 'cry', 'flock', 'amusement', 'faces', 'words', 'shepherd boy', 'sunset', 'feet']
# keywords_found in summarized:  ['sheep', 'wolf', 'cry', 'shepherd boy', 'villagers', 'boy', 'hillside']
# ['wolf', 'boy', 'villagers', 'hillside']
# time: 859 ms (started: 2023-04-11 09:33:36 +00:00)

# %%
question_model = T5ForConditionalGeneration.from_pretrained('ramsrigouthamg/t5_squad_v1')
question_tokenizer = T5Tokenizer.from_pretrained('ramsrigouthamg/t5_squad_v1')
question_model = question_model.to(device)
# Out:
# ...
# time: 13.9 s (started: 2023-04-11 09:33:37 +00:00)

# %%
def get_question(context,answer,model,tokenizer):
  text = "context: {} answer: {}".format(context,answer)
  encoding = tokenizer.encode_plus(text,max_length=384, pad_to_max_length=False,truncation=True, return_tensors="pt").to(device)
  input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

  outs = model.generate(input_ids=input_ids,
                                  attention_mask=attention_mask,
                                  early_stopping=True,
                                  num_beams=5,
                                  num_return_sequences=1,
                                  no_repeat_ngram_size=2,
                                  max_length=72)


  dec = [tokenizer.decode(ids,skip_special_tokens=True) for ids in outs]


  Question = dec[0].replace("question:","")
  Question= Question.strip()
  return Question



for wrp in wrap(summarized_text, 150):
  print (wrp)
print ("\n")

for answer in imp_keywords:
  ques = get_question(summarized_text,answer,question_model,question_tokenizer)
  print (ques)
  print (answer.capitalize())
  print ("\n")
# Out:
# A shepherd boy became bored when he watched over the sheep grazing on the hillside. To entertain himself, the boy sang out, “wolf! Wolf! The wolf is
# chasing sheep!” when the villagers heard the cry, they came running up the hills to drive the animal away - but when they arrived, there were no
# wolves. “don’t cry ‘wolf, boy,’ warned the villagers, ‘when there’s no dog!’ they angrily went back down the
#
#
# What animal was chasing sheep?
# Wolf
#
#
# What was the name of the shepherd who became bored?
# Boy
#
#
# Who came running up the hills to drive the animal away?
# Villagers
#
#
# Where were the sheep grazing?
# Hillside
#
#
# time: 10.5 s (started: 2023-04-11 09:33:51 +00:00)

# %%
# def generate_subjective_questions(summary, model, tokenizer):
#     max_len = 512
#     text = "generate subjective questions: {}".format(summary)
#     encoding = tokenizer.encode_plus(text, max_length=max_len, pad_to_max_length=False, truncation=True, return_tensors="pt").to(device)

#     input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

#     outs = model.generate(input_ids=input_ids,
#                           attention_mask=attention_mask,
#                           early_stopping=True,
#                           num_beams=3,
#                           num_return_sequences=1,
#                           no_repeat_ngram_size=2,
#                           min_length=75,
#                           max_length=300)

#     dec = [tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
#     questions = dec[0].split("?")[:-1]  # Split generated text on "?" to extract questions, remove last element which may be empty
#     questions = [question.strip() + "?" for question in questions]  # Add "?" back to the end of each question
#     return questions

# subjective_questions = generate_subjective_questions(summarized_text, question_model, question_tokenizer)
# print("Subjective Questions:")
# for question in subjective_questions:
#     print(question)
def generate_subjective_questions(summary, answer, model, tokenizer):
    input_text = "generate subjective questions: context: {} answer: {}".format(summary, answer)
    encoding = tokenizer.encode_plus(input_text, max_length=512, pad_to_max_length=False, truncation=True, return_tensors="pt").to(device)

    input_ids, attention_mask = encoding["input_ids"], encoding["attention_mask"]

    outs = model.generate(input_ids=input_ids,
                          attention_mask=attention_mask,
                          early_stopping=True,
                          num_beams=3,
                          num_return_sequences=1,
                          no_repeat_ngram_size=2,
                          min_length=75,
                          max_length=300)

    questions = [tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
    questions = [postprocesstext(q) for q in questions]
    questions = [q.strip() for q in questions]

    return questions

subjective_questions = generate_subjective_questions(summarized_text, imp_keywords[0], question_model, question_tokenizer)

print("Subjective Questions:")
for question in subjective_questions:
    print(question)
    print("Answer:", imp_keywords[0])
    print("\n")
# Out:
# Subjective Questions:
# Question: what animal was chasing sheep on the hillside when the shepherd boy sang out to entertain himself - but when they arrived, there were no wolves in the area besides a dog or wolf in it? : which animal did the villagers run to drive the animal away from the village, but there was no dog in their area?
# Answer: wolf
#
#
# time: 13.5 s (started: 2023-04-11 10:07:47 +00:00)

# %%
def grade_answers(answer, reference_answer, grading_scale):
    """
    Function to grade a user's answer based on a reference answer and a grading scale.
    
    Args:
    - answer (str): User's answer to be graded.
    - reference_answer (str): Reference answer for comparison.
    - grading_scale (dict): Dictionary containing grading scale as keys and corresponding grade descriptions as values.
    
    Returns:
    - grade (str): Grade based on the user's answer.
    """
    # Convert both answers to lowercase for case-insensitive comparison
    answer = answer.lower()
    reference_answer = reference_answer.lower()
    
    # Compare the user's answer with the reference answer
    if answer == reference_answer:
        grade = grading_scale["correct"]
    else:
        grade = grading_scale["incorrect"]
        
    return grade

# Example grading scale
grading_scale = {
    "correct": "Excellent",
    "incorrect": "Needs improvement"
}

# Example reference answer
reference_answer = "The quick brown fox jumps over the lazy dog."

# User's answer
user_answer = input("Enter your answer: ")

# Call the function to grade the user's answer
grade = grade_answers(user_answer, reference_answer, grading_scale)

# Print the grade
print("Grade: ", grade)
# Out:
# Enter your answer: hcghcg
# Grade:  Needs improvement
# time: 3.31 s (started: 2023-04-11 11:35:53 +00:00)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
import pke
import traceback

def generate_subjective_questions(summary, original_text, imp_keywords):
    questions = []
    try:
        extractor = pke.unsupervised.MultipartiteRank()
        extractor.load_document(input=original_text, language='en')
        pos = {'PROPN', 'NOUN'}
        stoplist = list(string.punctuation)
        stoplist += ['-lrb-', '-rrb-', '-lcb-', '-rcb-', '-lsb-', '-rsb-']
        stoplist += stopwords.words('english')
        extractor.candidate_selection(pos=pos)
        extractor.candidate_weighting(alpha=1.1, threshold=0.75, method='average')
        keyphrases = extractor.get_n_best(n=15)

        for val in keyphrases:
            keyword = val[0]
            if keyword in imp_keywords:
                question = "What is the significance of '{}' in the following statement? \n {}".format(keyword, summary)
                answer = val[0] + " is mentioned in the following statement: \n {}".format(original_text)
                questions.append({"question": question, "answer": answer})
    except:
        traceback.print_exc()

    return questions

# Call the function
questions_with_answers = generate_subjective_questions(summarized_text, text, imp_keywords)

# Print the questions with answers
for i, qa in enumerate(questions_with_answers[:5]):
    print("Question {}: {}".format(i+1, qa["question"]))
    print("Answer {}: {}".format(i+1, qa["answer"]))
    print("\n")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Question 1: What is the significance of 'wolf' in the following statement?
#  A shepherd boy became bored when he watched over the sheep grazing on the hillside. To entertain himself, the boy sang out, “wolf! Wolf! The wolf is chasing sheep!” when the villagers heard the cry, they came running up the hills to drive the animal away - but when they arrived, there were no wolves. “don’t cry ‘wolf, boy,’ warned the villagers, ‘when there’s no dog!’ they angrily went back down the
# Answer 1: wolf is mentioned in the following statement:
#   Once, there was a boy who became bored when he watched over the village sheep grazing on the hillside. To entertain himself, he sang out, “Wolf! Wolf! The wolf is chasing the sheep!”
# ...

# %%
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Question 1: What is the significance of 'wolf' in the following statement?
#   Once, there was a boy who became bored when he watched over the village sheep grazing on the hillside. To entertain himself, he sang out, “Wolf! Wolf! The wolf is chasing the sheep!”
# When the villagers heard the cry, they came running up the hill to drive the wolf away. But, when they arrived, they saw no wolf. The boy was amused when seeing their angry faces.
#
# “Don’t scream wolf, boy,” warned the villagers, “when there is no wolf!” They angrily went back down the hill.
#
# Later, the shepherd boy cried out once again, “Wolf! Wolf! The wolf is chasing the sheep!” To his amusement, he looked on as the villagers came running up the hill to scare the wolf away.
#
# ...
